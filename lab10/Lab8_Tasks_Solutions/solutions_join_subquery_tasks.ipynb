-- %% [markdown]
-- # Selecting data from many tables - Solutions

-- %% [markdown]
-- Here are the solutions of Tasks given in Lab 8: [join_subquery_books_store_tasks.html](https://wwwcourses.github.io/MySQL_DCA/pages/themes/JOIN_Subqueries_HandsOn/tasks/join_subquery_books_store_tasks.html)

-- %% [markdown]
-- ## Solutions

-- %% [markdown]
-- ### Task 1
--
-- Select (fname, lname,book_name) for all books published by all authors

-- %%
SELECT fname, lname, book_name
FROM authors as a
JOIN books as b
	ON a.id=b.author_id;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>fname</th>
--       <th>lname</th>
--       <th>book_name</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Kurt</td>
--       <td>Vonnegut</td>
--       <td>The Sirens of Titan</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>Kurt</td>
--       <td>Vonnegut</td>
--       <td>Mother Night</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>Kurt</td>
--       <td>Vonnegut</td>
--       <td>Cat's Cradle</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>Kurt</td>
--       <td>Vonnegut</td>
--       <td>God Bless You</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>Kurt</td>
--       <td>Vonnegut</td>
--       <td>Slaughterhouse</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>Kurt</td>
--       <td>Vonnegut</td>
--       <td>Breakfast of Champions</td>
--     </tr>
--     <tr>
--       <th>6</th>
--       <td>Douglas</td>
--       <td>Adams</td>
--       <td>The Hitchhiker's Guide to the Galaxy</td>
--     </tr>
--     <tr>
--       <th>7</th>
--       <td>Douglas</td>
--       <td>Adams</td>
--       <td>The Restaurant at the End of the Universe</td>
--     </tr>
--     <tr>
--       <th>8</th>
--       <td>Douglas</td>
--       <td>Adams</td>
--       <td>Life</td>
--     </tr>
--     <tr>
--       <th>9</th>
--       <td>Douglas</td>
--       <td>Adams</td>
--       <td>So Long</td>
--     </tr>
--     <tr>
--       <th>10</th>
--       <td>Douglas</td>
--       <td>Adams</td>
--       <td>Young Zaphod Plays It Safe</td>
--     </tr>
--     <tr>
--       <th>11</th>
--       <td>Douglas</td>
--       <td>Adams</td>
--       <td>Dirk Gently's Holistic Detective Agency</td>
--     </tr>
--     <tr>
--       <th>12</th>
--       <td>Douglas</td>
--       <td>Adams</td>
--       <td>Last Chance to See</td>
--     </tr>
--     <tr>
--       <th>13</th>
--       <td>Douglas</td>
--       <td>Adams</td>
--       <td>Mostly Harmless</td>
--     </tr>
--     <tr>
--       <th>14</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Alice's Adventures in Wonderland</td>
--     </tr>
--     <tr>
--       <th>15</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Through the Looking-Glass, and What Alice Found There</td>
--     </tr>
--     <tr>
--       <th>16</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Rhyme? And Reason?</td>
--     </tr>
--     <tr>
--       <th>17</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>A Tangled Tale</td>
--     </tr>
--     <tr>
--       <th>18</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Pillow Problems</td>
--     </tr>
--     <tr>
--       <th>19</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>La Guida di Bragia, a Ballad Opera for the Marionette Theatre</td>
--     </tr>
--     <tr>
--       <th>20</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Sylvie and Bruno</td>
--     </tr>
--     <tr>
--       <th>21</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Sylvie and Bruno Concluded</td>
--     </tr>
--     <tr>
--       <th>22</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Three Sunsets and Other Poems</td>
--     </tr>
--     <tr>
--       <th>23</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>The Hunting of the Snark</td>
--     </tr>
--     <tr>
--       <th>24</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>What the Tortoise Said to Achilles</td>
--     </tr>
--     <tr>
--       <th>25</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>A Syllabus of Plane Algebraic Geometry</td>
--     </tr>
--     <tr>
--       <th>26</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>The Fifth Book of Euclid Treated Algebraically</td>
--     </tr>
--     <tr>
--       <th>27</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>An Elementary Treatise on Determinants, With Their Application to Simultaneous Linear Equations and Algebraic Equations</td>
--     </tr>
--     <tr>
--       <th>28</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Euclid and his Modern Rivals</td>
--     </tr>
--     <tr>
--       <th>29</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Symbolic Logic Part I</td>
--     </tr>
--     <tr>
--       <th>30</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Symbolic Logic Part II</td>
--     </tr>
--     <tr>
--       <th>31</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>The Alphabet Cipher</td>
--     </tr>
--     <tr>
--       <th>32</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>The Game of Logic</td>
--     </tr>
--     <tr>
--       <th>33</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Curiosa Mathematica I</td>
--     </tr>
--     <tr>
--       <th>34</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>Curiosa Mathematica II</td>
--     </tr>
--     <tr>
--       <th>35</th>
--       <td>Georgi</td>
--       <td>Gospodinov</td>
--       <td>Natural Novel</td>
--     </tr>
--     <tr>
--       <th>36</th>
--       <td>Georgi</td>
--       <td>Gospodinov</td>
--       <td>And Other Stories</td>
--     </tr>
--     <tr>
--       <th>37</th>
--       <td>Georgi</td>
--       <td>Gospodinov</td>
--       <td>The Physics of Sorrow</td>
--     </tr>
--     <tr>
--       <th>38</th>
--       <td>Georgi</td>
--       <td>Gospodinov</td>
--       <td>Time Shelter</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 2
--
-- Select (book_name, pub_year) of the books written by Douglas Adams, sorted by book_name

-- %%
SELECT b.book_name,b.pub_year
FROM authors as a
JOIN books as b
	ON a.id = b.author_id
WHERE fname='Douglas' AND lname='Adams'
ORDER BY b.book_name;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>book_name</th>
--       <th>pub_year</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Dirk Gently's Holistic Detective Agency</td>
--       <td>1987</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>Last Chance to See</td>
--       <td>1990</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>Life</td>
--       <td>1982</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>Mostly Harmless</td>
--       <td>1992</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>So Long</td>
--       <td>1984</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>The Hitchhiker's Guide to the Galaxy</td>
--       <td>1979</td>
--     </tr>
--     <tr>
--       <th>6</th>
--       <td>The Restaurant at the End of the Universe</td>
--       <td>1980</td>
--     </tr>
--     <tr>
--       <th>7</th>
--       <td>Young Zaphod Plays It Safe</td>
--       <td>1986</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 3
--
-- Select (fname, lname, book_name, pub_year) for the author who has published the earliest book.
--
-- **Tip**: use `SELECT MIN(pub_year) FROM books` to select earliest pub_year

-- %%
SELECT a.fname, a.lname, b.book_name, b.pub_year
FROM authors as a
JOIN books as b
	ON a.id=b.author_id
WHERE b.pub_year = (
	SELECT MIN(pub_year) FROM books
);
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>fname</th>
--       <th>lname</th>
--       <th>book_name</th>
--       <th>pub_year</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>The Fifth Book of Euclid Treated Algebraically</td>
--       <td>1858</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 4
--
-- Select (fname, laname, books_count) for authors and the books count each have published, sorted descending by books_count

-- %%
SELECT a.fname, a.lname, COUNT(*) as books_count
FROM authors as a
JOIN books as b
	ON a.id=b.author_id
GROUP BY fname, lname
ORDER BY books_count DESC;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>fname</th>
--       <th>lname</th>
--       <th>books_count</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Lewis</td>
--       <td>Carroll</td>
--       <td>21</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>Douglas</td>
--       <td>Adams</td>
--       <td>8</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>Kurt</td>
--       <td>Vonnegut</td>
--       <td>6</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>Georgi</td>
--       <td>Gospodinov</td>
--       <td>4</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 5
--
-- Select authors.lname for authors who have published books after 1950

-- %%
SELECT DISTINCT a.lname
FROM authors as a
JOIN books as b
	ON a.id = b.author_id
WHERE pub_year>1950;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>lname</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>Gospodinov</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 6
--
-- Select book_name, authors.lname for books published after 1950

-- %%
SELECT b.book_name, a.lname
FROM authors as a
JOIN books as b
	ON a.id=b.author_id
WHERE b.pub_year>1950;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>book_name</th>
--       <th>lname</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>The Sirens of Titan</td>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>Mother Night</td>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>Cat's Cradle</td>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>God Bless You</td>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>Slaughterhouse</td>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>Breakfast of Champions</td>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>6</th>
--       <td>The Hitchhiker's Guide to the Galaxy</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>7</th>
--       <td>The Restaurant at the End of the Universe</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>8</th>
--       <td>Life</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>9</th>
--       <td>So Long</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>10</th>
--       <td>Young Zaphod Plays It Safe</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>11</th>
--       <td>Dirk Gently's Holistic Detective Agency</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>12</th>
--       <td>Last Chance to See</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>13</th>
--       <td>Mostly Harmless</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>14</th>
--       <td>Natural Novel</td>
--       <td>Gospodinov</td>
--     </tr>
--     <tr>
--       <th>15</th>
--       <td>And Other Stories</td>
--       <td>Gospodinov</td>
--     </tr>
--     <tr>
--       <th>16</th>
--       <td>The Physics of Sorrow</td>
--       <td>Gospodinov</td>
--     </tr>
--     <tr>
--       <th>17</th>
--       <td>Time Shelter</td>
--       <td>Gospodinov</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 7
--
-- Select fname,lname for the author who had sell most books

-- %% [markdown]
-- Solution 1: with 2 JOINs

-- %%
SELECT a.fname, a.lname, COUNT(*) as sell_count
FROM authors as a
JOIN books as b
	ON a.id = b.author_id
JOIN clients_books as cb
	ON b.id = cb.book_id
GROUP BY b.author_id
ORDER BY sell_count DESC
LIMIT 1;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>fname</th>
--       <th>lname</th>
--       <th>sell_count</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Georgi</td>
--       <td>Gospodinov</td>
--       <td>5</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- Solution 2: 1 JOIN and 1 independent subquery

-- %%
SELECT a.fname, a.lname
FROM authors as a
JOIN (
	SELECT count(b.author_id) as sell_count,author_id
	FROM books as b
	JOIN clients_books as cb
		ON b.id=cb.book_id
	GROUP BY b.author_id
	ORDER BY sell_count DESC
	LIMIT 1
) as t
ON a.id=t.author_id;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>fname</th>
--       <th>lname</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Georgi</td>
--       <td>Gospodinov</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 8
--
-- Select (book_name, pub_year) of the first and last book published by Douglas Adams

-- %% [markdown]
-- Solution 1: with JOIN and GROUP BY MIN/MAX

-- %%
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>book_name</th>
--       <th>pub_year</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Mostly Harmless</td>
--       <td>1992</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>The Hitchhiker's Guide to the Galaxy</td>
--       <td>1979</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 9
--
-- Select (name,city) for all clients who have associated city

-- %%
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>name</th>
--       <th>city</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Ivan</td>
--       <td>New York</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>Ivan</td>
--       <td>Sofia</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>Lily</td>
--       <td>Sofia</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>Merry</td>
--       <td>Paris</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>Peter</td>
--       <td>Lodon</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 10
--
-- Select (name,city) for all clients, no matter if there is a recorded city, sorted by name

-- %%
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>name</th>
--       <th>city</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Ivan</td>
--       <td>Sofia</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>Ivan</td>
--       <td>New York</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>John</td>
--       <td>None</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>Lily</td>
--       <td>Sofia</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>Merry</td>
--       <td>Paris</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>Peter</td>
--       <td>Lodon</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 11
--
-- Select client name, book_name for all clients and all books they have ordered

-- %%
-- Out:
-- (pymysql.err.OperationalError) (1054, "Unknown column 'cl.name' in 'field list'")
-- [SQL: SELECT cl.name, b.book_name
-- FROM clients as c
-- JOIN clients_books as cb
-- 	ON c.id=cb.client_id
-- JOIN books as b
-- 	ON b.id=cb.book_id limit 1000]
-- (Background on this error at: https://sqlalche.me/e/14/e3q8)

-- %% [markdown]
-- ### Task 12
--
-- Select clients.name, book_name, authors.lname for all clients and all books each client had ordered

-- %%
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>name</th>
--       <th>book_name</th>
--       <th>lname</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Ivan</td>
--       <td>The Hitchhiker's Guide to the Galaxy</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>John</td>
--       <td>The Hitchhiker's Guide to the Galaxy</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>John</td>
--       <td>So Long</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>Merry</td>
--       <td>Dirk Gently's Holistic Detective Agency</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>John</td>
--       <td>Alice's Adventures in Wonderland</td>
--       <td>Carroll</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>Ivan</td>
--       <td>Natural Novel</td>
--       <td>Gospodinov</td>
--     </tr>
--     <tr>
--       <th>6</th>
--       <td>Lily</td>
--       <td>Natural Novel</td>
--       <td>Gospodinov</td>
--     </tr>
--     <tr>
--       <th>7</th>
--       <td>Ivan</td>
--       <td>The Physics of Sorrow</td>
--       <td>Gospodinov</td>
--     </tr>
--     <tr>
--       <th>8</th>
--       <td>Merry</td>
--       <td>The Physics of Sorrow</td>
--       <td>Gospodinov</td>
--     </tr>
--     <tr>
--       <th>9</th>
--       <td>Lily</td>
--       <td>The Physics of Sorrow</td>
--       <td>Gospodinov</td>
--     </tr>
--     <tr>
--       <th>10</th>
--       <td>Ivan</td>
--       <td>The Sirens of Titan</td>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>11</th>
--       <td>Ivan</td>
--       <td>God Bless You</td>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>12</th>
--       <td>Ivan</td>
--       <td>Slaughterhouse</td>
--       <td>Vonnegut</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 13
--
-- Select book_name for all books ordered by 'Ivan'

-- %%
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>book_name</th>
--       <th>name</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>The Sirens of Titan</td>
--       <td>Ivan</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>God Bless You</td>
--       <td>Ivan</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>Slaughterhouse</td>
--       <td>Ivan</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>The Hitchhiker's Guide to the Galaxy</td>
--       <td>Ivan</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>Natural Novel</td>
--       <td>Ivan</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>The Physics of Sorrow</td>
--       <td>Ivan</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 14
--
-- Select * for all clients who have not order any book

-- %%
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>id</th>
--       <th>name</th>
--       <th>age</th>
--       <th>client_id</th>
--       <th>book_id</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>4</td>
--       <td>Peter</td>
--       <td>35</td>
--       <td>None</td>
--       <td>None</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 15
--
-- Select how many books each client have ordered

-- %%
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>name</th>
--       <th>book_count</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Ivan</td>
--       <td>6</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>John</td>
--       <td>3</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>Merry</td>
--       <td>2</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>Lily</td>
--       <td>2</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 16
--
-- Select book_name, name, age for books ordered by clients aged > 30 years

-- %%
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>book_name</th>
--       <th>name</th>
--       <th>age</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>The Hitchhiker's Guide to the Galaxy</td>
--       <td>John</td>
--       <td>34</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>So Long</td>
--       <td>John</td>
--       <td>34</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>Alice's Adventures in Wonderland</td>
--       <td>John</td>
--       <td>34</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 17
--
-- Select clients.name, books.book_name, authors.lname for books ordered by clients aged > 20 years

-- %%
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>name</th>
--       <th>book_name</th>
--       <th>lname</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Ivan</td>
--       <td>The Sirens of Titan</td>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>Ivan</td>
--       <td>God Bless You</td>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>Ivan</td>
--       <td>Slaughterhouse</td>
--       <td>Vonnegut</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>Ivan</td>
--       <td>The Hitchhiker's Guide to the Galaxy</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>Ivan</td>
--       <td>Natural Novel</td>
--       <td>Gospodinov</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>Ivan</td>
--       <td>The Physics of Sorrow</td>
--       <td>Gospodinov</td>
--     </tr>
--     <tr>
--       <th>6</th>
--       <td>John</td>
--       <td>The Hitchhiker's Guide to the Galaxy</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>7</th>
--       <td>John</td>
--       <td>So Long</td>
--       <td>Adams</td>
--     </tr>
--     <tr>
--       <th>8</th>
--       <td>John</td>
--       <td>Alice's Adventures in Wonderland</td>
--       <td>Carroll</td>
--     </tr>
--     <tr>
--       <th>9</th>
--       <td>Lily</td>
--       <td>Natural Novel</td>
--       <td>Gospodinov</td>
--     </tr>
--     <tr>
--       <th>10</th>
--       <td>Lily</td>
--       <td>The Physics of Sorrow</td>
--       <td>Gospodinov</td>
--     </tr>
--   </tbody>
-- </table>

-- %% [markdown]
-- ### Task 18
--
-- Select city, clients.name for the client who have ordered most books

-- %%
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>name</th>
--       <th>city</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>Ivan</td>
--       <td>Sofia</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>Ivan</td>
--       <td>New York</td>
--     </tr>
--   </tbody>
-- </table>
